# %%
print("hellow world")
num1=4
num2=3
print(num1+num2)
length=4
breath=6
area=length*breath
print(area)

a=2
b=7
print(a)
print(b)    


length=2
breadth=2
height=4
perimeter=length+breadth+height
print(perimeter)

a=10 #int
b=12.4   #float
c="hello world"   #string
d=True   #boolen which is o and 1 either true or false

print(a,b,c,d)           #shift+enter for direct run


# string should written in 3 way   
e='hellow world'
e="hellow world"
e='''hellow world'''
e="12"#string
e="ajavv" #string
e=12 # int
e="12.3hvhvh%5455" #string


a=2
b=4.4
c="hello world"
print(type(a))
print(type(b))
print(type(c))

#command function = int() float() str()
#type casting one data type convert into another
a=10
b=float(a)
print(b)

a=10.4
b=int(a)
print(b)
# Out:
# hellow world
# 7
# 24
# 2
# 7
# 8
# 10 12.4 hello world True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 10.0
# 10

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(type(a))
print(type(A))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=10
b=str(a)
b
# Out:
# '10'

# %%
a=10.4
b=str(a)
b
a=True # None True False should be capital 1st letter
b=str(a)
b
a=False
b=str(a)
b
# Out:
# 'False'

# %%
#arthametic operator +-*/**/%/////       = + is assignment operator  variable abcd...z
# vanako power
a=10
b=3
c=a+b
print(c)
a=10
b=3
c=a-b
print(c)
a=10
b=3
c=a*b
print(c)
a=10
b=3
c=a/b
print(c)

a=10   #3*3+1 which is 1 remainder
b=3
c=a%b   #      %percent show reminder
print(c)
a=10
b=3
c=a**b   #** is power like a**2
print(c)

a=" hellow"    # string ma addition matra milxa,,,   add garda duitain string hunu paryo
b="  world"
c=a+b  # concatination vanako jodinu
print(c) 




a="hellow world\n"
b=2
c=a*b   # multiply ko case ma euta string euta integer
print(c)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
#  hellow  world
# hellow world
# hellow world

# %%
a=True      # because true=1 and false=0
b=False
c=a+b
print(c)

a=True      # because true=1 and false=0
b=False
c=a-b
print(c)

a=True      # because true=1 and false=0
b=False
c=a*b
print(c)  

a=True      # because true=1 and false=0
b=False
c=a/b     #divide garda error hunxa...python ma infinity hudaina    /*+- matra  hunxa
print(c)
# Out:
# 1
# 1
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[28], line 18
#      16 a=True      # because true=1 and false=0
#      17 b=False
# ---> 18 c=a/b
#      19 print(c)
#
# ZeroDivisionError: division by zero

# %%
# variable define garda 
Apple=10
a=Apple       # 2 type  of variable 1.user and predefined variable
a
# Out:
# 10

# %%
Apple=10
apple=10

# %%
# Basic IO operation     [*] strict tapaiko complete xain
a=input()
# Out:
# 10

# %%
# Basic IO operation     [*] strict tapaiko complete xain
a=input()

# %%
a=input("Enter value of a=")
print(a)

# %%
name=input("Enter your name=")
print("Your name is=",name)
# Out:
# Enter your name=ram
# Your name is= ram

# %%
name=input("Enter your name=")
print("Your name is=",name)
# Out:
# Enter your name=hey u
# Your name is= hey u

# %%
name=input("Enter your name=")
print("my name is",name)
# Out:
# Enter your name=manoj kumar yadav
# my name is manoj kumar yadav

# %%
from IPython.display import Audio

 = 'AtV3Tjmi4YmpJFX9aSsFAv6GWMsz2yyPua4aJPhTE3pR'
Audio(, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from IPython.display import Audio
#       3 sound_file = 'AtV3Tjmi4YmpJFX9aSsFAv6GWMsz2yyPua4aJPhTE3pR'
# ----> 4 Audio(AtV3Tjmi4YmpJFX9aSsFAv6GWMsz2yyPua4aJPhTE3pR, autoplay=True)
#
# NameError: name 'AtV3Tjmi4YmpJFX9aSsFAv6GWMsz2yyPua4aJPhTE3pR' is not defined

# %%
from IPython.display import Audio

# Load the sound file
sound_file = r"‪C:\Users\ACER\Downloads\gutar_tune.mp3"

# Play the sound
Audio(sound_file, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 7
#       4 sound_file = r"‪C:\Users\ACER\Downloads\gutar_tune.mp3"
#       6 # Play the sound
# ----> 7 Audio(sound_file, autoplay=True)
#
# File ~\anaconda3\lib\site-packages\IPython\lib\display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %%
from IPython.display import Audio

# Load the sound file
sound_file = r"C:\Users\ACER\Downloads\gutar_tune.mp3"

# Play the sound
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Load the sound file3"

sound_file = r"C:\Users\ACER\Downloads\gutar_tune.mp3"
# Play the sound
Audio(sound_file, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
dj=r"C:\Users\ACER\Downloads\gutar_tune.mp"
Audio(data=dj, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from IPython.display import Audio
#       2 dj=r"C:\Users\ACER\Downloads\gutar_tune.mp"
# ----> 3 Audio(data=dj, autoplay=True)
#
# File ~\anaconda3\lib\site-packages\IPython\lib\display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %%
#Python supports the usual logical conditions from mathematics:
#Equals: a == b  ,Not Equals: a != b  .Less than: a < b  ,Less than or equal to: a <= b    ,Greater than: a > b
 #Greater than or equal to: a >= b
    
    #if...else condition
a = 33
b = 200
if b > a:
  print("b is greater than a",)
elif a != b:
 print("a and b are not equal")
# Out:
# b is greater than a

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
 print("a is greater than b")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a != b:
    print("a is not equal to b")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is not equal to b

# %%
a=5
b=4
if b>a:
 print("b is greater than a")
else:
 print("a is greater than b")
# Out:
# a is greater than b

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
#One line if else statement:   this tag show exactly optput

a = 2
b = 330
print("A") if a > b else print("B")



a = 400
b = 330
print("A") if a > b else print("B")    #this tag show  <> greater or smaller


a = 400
b = 330
print("A") if a < b else print("B") 



a = 2
b = 330
print("A") if a != b else print("B")

a = 330
b = 6767
print("A") if a != b else print("B")
# Out:
# B
# A
# B
# A
# A

# %%
#One line if else statement, with 3 conditions:

a = 330
b = 330
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# =

# %%
a=input("Enter a= ")
b=input("Enter b= ")
c=a+b
print(c)
# Out:
# Enter a= 10
# Enter b= 10
# 1010

# %%
a=int(input("Enter a= "))
b=int(input("Enter b= "))
c=a+b
print(c)
# Out:
# Enter a= 10
# Enter b= 10
# 20

# %%
a=float(input("Enter a= "))
b=float(input("Enter b= "))
c=a+b
print(c)
# Out:
# Enter a= 10.9
# Enter b= 28.3
# 39.2

# %%
p=float(input("Enter p= "))
t=float(input("Enter t= "))
r=float(input("Enter r= "))
i=p*t*r/100
print("The value of i= ",i)
# Out:
# Enter p= 344
# Enter t= 4
# Enter r= 4.4
# The value of i=  60.544000000000004

# %%
name=input("Enter name= ")      #concatination vaninxa
age=int(input("Enter age= "))
add=input("Enter add= ")

info= "Hello my name is" +name+ "i am" + str(age) + "i am from"+add    # string sng concat 
print(info)
# Out:
# Enter name= manoj kumar yadav
# Enter age= 22
# Enter add= kathmandu
# Hello my name ismanoj kumar yadavi am22i am fromkathmandu

# %%
name=input("Enter name a= ")
physic=int(input("Enter physic marks= "))
math=int(input("Enter math marks= "))
nepali=int(input("Enter nepali marks= "))
chemistry=int(input("Enter chemistry marks= "))
social=int(input("Enter social marks= "))
total=physic +chemistry +math +nepali +social
per= total/5
print("Hello", name, "your total mark is", total, "and per is = ",per )
# Out:
# Enter name a= manoj
# Enter physic marks= 50
# Enter math marks= 34
# Enter nepali marks= 23
# Enter chemistry marks= 45
# Enter social marks= 56
# Hello manoj  your total mark is 208 and per is =  41.6
